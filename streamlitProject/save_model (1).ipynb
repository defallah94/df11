# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X = df.drop(columns = 'Outcome', axis=1)
Y = df['Outcome']

# %%
print('X',X)
# Out:
# X      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print('Y',Y)
# Out:
# Y 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
from sklearn.svm import SVC
SVC_i = SVC()
SVC_i.fit(X_train, Y_train)
# Out:
# SVC()

# %%
X_train1 = SVC_i.predict(X_test)
training = accuracy_score(X_train1, Y_test)
training
# Out:
# 0.7857142857142857

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C' : [ 1, 10, 100, 1000], 'gamma' : [0.1,1,2, 3]}

# %%
from sklearn.svm import SVC
GS1 = GridSearchCV(SVC(),param_grid =param_grid, verbose = 3)
GS1.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.650 total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=0.1;, score=0.650 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.650 total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.650 total time=   0.1s
# [CV 5/5] END ....................C=1, gamma=0.1;, score=0.656 total time=   0.1s
# [CV 1/5] END ......................C=1, gamma=1;, score=0.650 total time=   0.0s
# [CV 2/5] END ......................C=1, gamma=1;, score=0.650 total time=   0.0s
# [CV 3/5] END ......................C=1, gamma=1;, score=0.650 total time=   0.0s
# [CV 4/5] END ......................C=1, gamma=1;, score=0.650 total time=   0.0s
# [CV 5/5] END ......................C=1, gamma=1;, score=0.656 total time=   0.0s
# [CV 1/5] END ......................C=1, gamma=2;, score=0.650 total time=   0.0s
# ...

# %%
X_train2 = SVC_i.predict(X_test)
training = accuracy_score(X_train2, Y_test)
training
# Out:
# 0.7857142857142857

# %%
# accuracy score on the training data
X_train_prediction = SVC_i.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
training_data_accuracy
# Out:
# 0.7638436482084691

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_predictions = SVC_i.predict(X_test)
print(confusion_matrix(Y_test, y_predictions))
# Out:
# [[95  5]
#  [28 26]]

# %%
print(classification_report(Y_test, y_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.95      0.85       100
#            1       0.84      0.48      0.61        54
#
#     accuracy                           0.79       154
#    macro avg       0.81      0.72      0.73       154
# weighted avg       0.80      0.79      0.77       154

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = SVC_i.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [1]
# The person is diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
input_data = (1,150,60,15,180,30.8,0.586,40)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = SVC_i.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [1]
# The person is diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
Pregnancies = int(input('Enter the number of pregnancies: '))
Glucose = int(input('Enter the glucose level: '))
BloodPressure = int(input('Enter the blood pressure: '))
SkinThickness = int(input('Enter the skin thickness: '))
Insulin = int(input('Enter the insulin level: '))
BMI = float(input('Enter the BMI: '))
DiabetesPedigreeFunction = float(input('Enter the diabetes pedigree function: '))
Age = int(input('Enter the age: '))
# Out:
# Enter the number of pregnancies: 0
# Enter the glucose level: 90
# Enter the blood pressure: 72
# Enter the skin thickness: 35
# Enter the insulin level: 0
# Enter the BMI: 36.6
# Enter the diabetes pedigree function: 0.564
# Enter the age: 50

# %%
data = [Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age]

# %%
prediction = SVC_i.predict([data])
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [0]
# The person is not diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename = 'SVC_i_model.sav'
pickle.dump(SVC_i, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('/content/SVC_i_model.sav', 'rb'))

# %%
input_data = (1,85,66,29,0,26.6,0.351,30)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
prediction = loaded_model.predict(input_data_reshaped)
print(prediction)
if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [0]
# The person is not diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
